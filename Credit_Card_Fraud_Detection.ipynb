# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/drive/MyDrive/machinelearning/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# describe dataset
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# checking the null data
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# duplicate data
df.duplicated().sum()
# Out:
# 1081

# %%
# Checking the fraud and legit transaction 0 -> legit(normal), 1 -> fraud
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# ## The Dataset is Highly imbalance

# %% [markdown]
# 1. **Fraud Transaction -> 1**
# 2. **Normal (Legit) Transaction -> 0**

# %%
# Seprating the data for analysis
normal = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
normal.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
# description of  Transaction amount for normal 
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# description of  Transaction amount for fraud 
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# comparing bot the transaction data
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Under Sampling Data
#
# Build a Sample containing similar data of normal and fraud transaction
#
# Fraud data -> 492

# %%
legit_sample = normal.sample(n= 492)

# %%
legit_sample.shape
# Out:
# (492, 31)

# %% [markdown]
# Now dataset is balanced
#
# concatenating the dataset of fraud and normal

# %%
new_df = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 103598   68728.0 -3.402078  1.787935 -0.586769 -0.310629 -0.236211  0.977002
# 283899  171972.0 -1.805874  2.132128 -1.271206 -0.385644 -0.396966 -0.988812
# 282094  170646.0  0.089351  0.902509  0.014968 -0.754058  0.800793 -0.698574
# 233032  147415.0 -1.182983  2.406816 -0.021267  4.211767  0.235606  0.810250
# 68087    52826.0 -1.060413 -2.045966  0.989128 -1.175655 -2.226071  0.631708
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 103598  0.086591  1.090811  0.473163  ...  0.055004  0.731200  0.212759
# 283899 -0.276885  1.392421 -0.090848  ...  0.135808  0.395990 -0.096868
# 282094  1.076230 -0.213990 -0.128969  ... -0.293725 -0.628526 -0.015685
# 233032 -0.047334  0.978743 -2.330010  ... -0.067025 -0.332220  0.281593
# 68087   0.809865  0.095996 -2.765027  ...  0.036618 -0.561008  1.372891
#
# ...

# %%
# value of new dataset
new_df['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
# preformaning the groupby with the new dataset
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92974.729675 -0.040294 -0.036757 -0.039253 -0.018253 -0.065615
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.041777  0.041221  0.063988 -0.089585  ...  0.045624  0.038395
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.010268 -0.001823 -0.001818 -0.001436  0.004735  0.010679  0.004484
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      103.688699
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Spliting the dataset into independent and dependent data

# %%
X = new_df.drop(columns = 'Class', axis = 1)

# %%
y = new_df['Class']

# %%
X.shape
# Out:
# (984, 30)

# %%
X.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
y.shape
# Out:
# (984,)

# %% [markdown]
# # Spliting the dataset into Train and Test

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y,test_size = 0.2, stratify = y, random_state = 2)

# %%
print('X data : ', X.shape, ' '*5 ,"X_train : " , X_train.shape)
print('--'*30)
print('y data : ', y.shape, ' '*5,  "y_train", y_train.shape)
print('--'*30)
print("X_test", X_test.shape)
print('--'*30)
print("y_test", y_test.shape)
# Out:
# X data :  (984, 30)       X_train :  (787, 30)
# ------------------------------------------------------------
# y data :  (984,)       y_train (197, 30)
# ------------------------------------------------------------
# X_test (787,)
# ------------------------------------------------------------
# y_test (197,)

# %% [markdown]
# # Model Creation

# %%
model = LogisticRegression()

# %%
# training the data
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# model evaluation and accuracy score printing for training data
x_train_pred = model.predict(x_train)
train_data_accuracy = accuracy_score(x_train_pred, y_train)

# %%
print('Accuracy of Training Data : ', train_data_accuracy)
# Out:
# Accuracy of Training Data :  0.9418604651162791

# %%
# model evaluation and accuracy score printing for testing data
x_test_pred = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_pred, y_test)

# %%
print('Accuracy of Testing Data : ', test_data_accuracy)
# Out:
# Accuracy of Testing Data :  0.9256756756756757

# %% [markdown]
# # Here the data is Perfectly fitted in the train and also in the test data.

# %% [markdown]
# # Saving the Model

# %%
import pickle

# %%
pickle.dump(model, open('model.pkl', 'wb'))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
